# %% [markdown]
# # ETL en base a EDA

# %% [markdown]
# ### Importamos galerias

# %%
import pandas as pd

# %% [markdown]
# ### Cargamos archivos csv en data frames

# %%
hechos = 'hechos.csv'
hechosxlsx = 'hechos.xlsx'
hechos_victimas= 'homicidios.xlsx - VICTIMAS.csv'
df_hechos_original = pd.read_csv(hechos, encoding='latin-1')
df_hechos_victimas_original = pd.read_csv(hechos_victimas, encoding='latin-1')

# %% [markdown]
# ### Visualizamos el data frame hechos

# %%
df_hechos_original.head(10)
# Out:
#           ID  N_VICTIMAS      FECHA    AAAA   MM    DD      HORA  HH  \
# 0  2016-0001         1.0   1/1/2016  2016.0  1.0   1.0   4:00:00   4
# 1  2016-0002         1.0   1/2/2016  2016.0  1.0   2.0   1:15:00   1
# 2  2016-0003         1.0   1/3/2016  2016.0  1.0   3.0   7:00:00   7
# 3  2016-0004         1.0  1/10/2016  2016.0  1.0  10.0   0:00:00   0
# 4  2016-0005         1.0  1/21/2016  2016.0  1.0  21.0   5:20:00   5
# 5  2016-0008         1.0  1/24/2016  2016.0  1.0  24.0  18:30:00  18
# 6  2016-0009         1.0  1/24/2016  2016.0  1.0  24.0  19:10:00  19
# 7  2016-0010         1.0  1/29/2016  2016.0  1.0  29.0  15:20:00  15
# 8  2016-0012         1.0   2/8/2016  2016.0  2.0   8.0   1:20:00   1
# 9  2016-0013         1.0  2/10/2016  2016.0  2.0  10.0  11:30:00  11
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# 5             AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA  ...     NaN
# 6               NOGOYA Y JOAQUIN V. GONZALES         CALLE  ...     NaN
# 7        AV GENERAL PAZ Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 8         AV BELGRANO Y BERNARDO DE IRIGOYEN       AVENIDA  ...     NaN
# 9                         AV ENTRE RIOS 1366       AVENIDA  ...  1366.0
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
# 5                         ESCALADA AV.
# 6                 GONZALEZ, JOAQUIN V.
# 7                  DE LOS CORRALES AV.
# 8                IRIGOYEN, BERNARDO DE
# 9                                  NaN
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...    8.0
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.    9.0
# 2                                ENTRE RIOS AV. 2034    1.0
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.    8.0
# 4            SAN JUAN AV. y SAENZ PEÃA, LUIS, PRES.    1.0
# 5                   27 DE FEBRERO AV. y ESCALADA AV.    8.0
# 6                      NOGOYA y GONZALEZ, JOAQUIN V.   11.0
# 7               PAZ, GRAL. AV. y DE LOS CORRALES AV.    9.0
# 8               BELGRANO AV. e IRIGOYEN, BERNARDO DE    1.0
# 9                                ENTRE RIOS AV. 1366    1.0
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# 5   Point (101721.59002217 93844.25656649)  -58.44451316  -34.68475866
# 6   Point (96545.87592078 102330.67262199)  -58.50095869  -34.60825440
# 7    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 8  Point (107595.35084333 101797.50052813)  -58.38048577  -34.61303893
# 9  Point (106616.41069662 100496.44662323)  -58.39114932  -34.62477387
#
#       PARTICIPANTES VICTIMA      ACUSADO
# 0         MOTO-AUTO    MOTO         AUTO
# 1    AUTO-PASAJEROS    AUTO    PASAJEROS
# 2         MOTO-AUTO    MOTO         AUTO
# 3           MOTO-SD    MOTO           SD
# 4    MOTO-PASAJEROS    MOTO    PASAJEROS
# 5  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 6         MOTO-AUTO    MOTO         AUTO
# 7         MOTO-AUTO    MOTO         AUTO
# 8       MOTO-CARGAS    MOTO       CARGAS
# 9       PEATON-AUTO  PEATON         AUTO
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Columnas del Data Frame

# %%
df_hechos_original.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA', 'ACUSADO'],
#       dtype='object')

# %% [markdown]
# ### Borramos columnas no necesarias

# %%
df_hechos_modificado = df_hechos_original.drop(['AAAA', 'MM', 'DD', 'HORA' , 'XY (CABA)','PARTICIPANTES'],axis=1 )

# %% [markdown]
# ### Visualizamos

# %%
df_hechos_modificado.head(5)
# Out:
#           ID  N_VICTIMAS      FECHA HH  \
# 0  2016-0001         1.0   1/1/2016  4
# 1  2016-0002         1.0   1/2/2016  1
# 2  2016-0003         1.0   1/3/2016  7
# 3  2016-0004         1.0  1/10/2016  0
# 4  2016-0005         1.0  1/21/2016  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ    PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA    ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA    LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA      SAN JUAN AV.
#
#    Altura                                Cruce  \
# 0     NaN  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1     NaN                  DE LOS CORRALES AV.
# 2  2034.0                                  NaN
# 3     NaN             VILLEGAS, CONRADO, GRAL.
# 4     NaN              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada  COMUNA         pos x  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...     8.0  -58.47533969
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.     9.0  -58.50877521
# 2                                ENTRE RIOS AV. 2034     1.0  -58.39040293
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.     8.0  -58.46503904
# 4            SAN JUAN AV. y SAENZ PEÃA, LUIS, PRES.     1.0  -58.38718297
#
#           pos y VICTIMA    ACUSADO
# 0  -34.68757022    MOTO       AUTO
# 1  -34.66977709    AUTO  PASAJEROS
# 2  -34.63189362    MOTO       AUTO
# 3  -34.68092974    MOTO         SD
# 4  -34.62246630    MOTO  PASAJEROS

# %% [markdown]
# ### Importamos en formato csv

# %%
df_hechos_modificado.to_csv('hechos_clean.csv', index=False)

# %% [markdown]
# ### Cambiamos el nombre de la columna ID_hecho del data frame victimas por ID

# %%
df_hechos_victimas_modificado = df_hechos_victimas_original.rename(columns={'ID_hecho': 'ID'})

# %% [markdown]
# ### Borramos columnas que no utilizaremos en el data frame victimas

# %%
df_hechos_victimas_modificado_1 = df_hechos_victimas_modificado.drop([ 'AAAA', 'MM', 'DD'],axis=1 )

# %% [markdown]
# ### Visualizamos

# %%
df_hechos_victimas_modificado_1.head(5)
# Out:
#           ID      FECHA        ROL VICTIMA       SEXO EDAD FECHA_FALLECIMIENTO
# 0  2016-0001   1/1/2016  CONDUCTOR    MOTO  MASCULINO   19            1/1/2016
# 1  2016-0002   2/1/2016  CONDUCTOR    AUTO  MASCULINO   70            2/1/2016
# 2  2016-0003   3/1/2016  CONDUCTOR    MOTO  MASCULINO   30            3/1/2016
# 3  2016-0004  10/1/2016  CONDUCTOR    MOTO  MASCULINO   18                  SD
# 4  2016-0005  21/1/2016  CONDUCTOR    MOTO  MASCULINO   29            1/2/2016

# %% [markdown]
# ### Exportamos en formato .csv

# %%
df_hechos_victimas_modificado_1.to_csv('victimas_clean.csv', index=False )

# %% [markdown]
# ### Hacemos un merge en base a la columna ID de los data frame hechos clean  y victimas clean

# %%
df_merged = pd.merge(df_hechos_modificado, df_hechos_victimas_modificado_1, on='ID', how='inner')

# %% [markdown]
# ### Visualizamos

# %%
df_merged.head(5)
# Out:
#           ID  N_VICTIMAS    FECHA_x HH  \
# 0  2016-0001         1.0   1/1/2016  4
# 1  2016-0002         1.0   1/2/2016  1
# 2  2016-0003         1.0   1/3/2016  7
# 3  2016-0004         1.0  1/10/2016  0
# 4  2016-0005         1.0  1/21/2016  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ    PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA    ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA    LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA      SAN JUAN AV.
#
#    Altura                                Cruce  \
# 0     NaN  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1     NaN                  DE LOS CORRALES AV.
# 2  2034.0                                  NaN
# 3     NaN             VILLEGAS, CONRADO, GRAL.
# 4     NaN              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada  ...         pos x  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...  ...  -58.47533969
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.  ...  -58.50877521
# 2                                ENTRE RIOS AV. 2034  ...  -58.39040293
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.  ...  -58.46503904
# 4            SAN JUAN AV. y SAENZ PEÃA, LUIS, PRES.  ...  -58.38718297
#
#           pos y VICTIMA_x    ACUSADO    FECHA_y        ROL VICTIMA_y  \
# 0  -34.68757022      MOTO       AUTO   1/1/2016  CONDUCTOR      MOTO
# 1  -34.66977709      AUTO  PASAJEROS   2/1/2016  CONDUCTOR      AUTO
# 2  -34.63189362      MOTO       AUTO   3/1/2016  CONDUCTOR      MOTO
# 3  -34.68092974      MOTO         SD  10/1/2016  CONDUCTOR      MOTO
# 4  -34.62246630      MOTO  PASAJEROS  21/1/2016  CONDUCTOR      MOTO
#
#         SEXO EDAD FECHA_FALLECIMIENTO
# 0  MASCULINO   19            1/1/2016
# 1  MASCULINO   70            2/1/2016
# 2  MASCULINO   30            3/1/2016
# 3  MASCULINO   18                  SD
# 4  MASCULINO   29            1/2/2016
#
# [5 rows x 21 columns]

# %%
df_merged.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA_x', 'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE',
#        'Calle', 'Altura', 'Cruce', 'Dirección Normalizada', 'COMUNA', 'pos x',
#        'pos y', 'VICTIMA_x', 'ACUSADO', 'FECHA_y', 'ROL', 'VICTIMA_y', 'SEXO',
#        'EDAD', 'FECHA_FALLECIMIENTO'],
#       dtype='object')

# %% [markdown]
# ### Elimino columnas duplicadas

# %%
df_merged_clean = df_merged.drop(['FECHA_y', 'VICTIMA_y' ], axis = 1)

# %% [markdown]
# ### Exportamos en formato csv

# %%
df_merged_clean.to_csv('merged_clean.csv', index=False)
